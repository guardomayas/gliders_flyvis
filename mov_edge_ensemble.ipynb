# %%
import matplotlib.colors as mcolors
from utils.setup_environment import *
from flyvis import EnsembleView, results_dir
from flyvis.analysis.moving_bar_responses import plot_angular_tuning
from flyvis.analysis.visualization import plt_utils
from flyvis.utils.color_utils import color_to_cmap
from flyvis.datasets.moving_bar import MovingEdge
from flyvis.analysis.clustering import EnsembleEmbedding, get_cluster_to_indices
from flyvis.utils.activity_utils import CentralActivity

# %%
from flyvis import results_dir
from flyvis.network import NetworkView

# model are already sorted by task error
# we take the best task-performing model from the pre-sorted ensemble
network_view = NetworkView(results_dir / "flow/0000/000")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 6
#       2 from flyvis.network import NetworkView
#       3
#       4 # model are already sorted by task error
#       5 # we take the best task-performing model from the pre-sorted ensemble
# ----> 6 network_view = NetworkView(results_dir / "flow/0000/000")
#
# File ~/NUIN/flyvis/flyvis/network/network_view.py:100, in NetworkView.__init__(self, network_dir, network_class, root_dir, connectome_getter, checkpoint_mapper, best_checkpoint_fn, best_checkpoint_fn_kwargs, recover_fn)
#      85 def __init__(
#      86     self,
#      87     network_dir: Union[str, PathLike, NetworkDir],
#    (...)     97     recover_fn: Callable = recover_network,
#      98 ):
#      99     self.network_class = network_class
# --> 100     self.dir, self.name = self._resolve_dir(network_dir, root_dir)
#     101     self.root_dir = root_dir
#     102     self.connectome_getter = connectome_getter
#
# File ~/NUIN/flyvis/flyvis/network/network_view.py:347, in NetworkView._resolve_dir(self, network_dir, root_dir)
#     345         network_dir = Directory(network_dir)
#     346 if not network_dir.config.type == "NetworkDir":
# --> 347     raise ValueError(f"NetworkDir not found at {network_dir.path}.")
#     348 name = os.path.sep.join(network_dir.path.parts[-3:])
#     349 return network_dir, name
#
# ValueError: NetworkDir not found at /home/guardomayas/flyvis_data/results/flow/0000/000.

# %%
# we load the best task-performing model from the presorted ensemble
network_view = NetworkView(results_dir / "flow/0000/000")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 2
#       1 # we load the best task-performing model from the presorted ensemble
# ----> 2 network_view = NetworkView(results_dir / "flow/0000/000")
#
# File ~/NUIN/flyvis/flyvis/network/network_view.py:100, in NetworkView.__init__(self, network_dir, network_class, root_dir, connectome_getter, checkpoint_mapper, best_checkpoint_fn, best_checkpoint_fn_kwargs, recover_fn)
#      85 def __init__(
#      86     self,
#      87     network_dir: Union[str, PathLike, NetworkDir],
#    (...)     97     recover_fn: Callable = recover_network,
#      98 ):
#      99     self.network_class = network_class
# --> 100     self.dir, self.name = self._resolve_dir(network_dir, root_dir)
#     101     self.root_dir = root_dir
#     102     self.connectome_getter = connectome_getter
#
# File ~/NUIN/flyvis/flyvis/network/network_view.py:347, in NetworkView._resolve_dir(self, network_dir, root_dir)
#     345         network_dir = Directory(network_dir)
#     346 if not network_dir.config.type == "NetworkDir":
# --> 347     raise ValueError(f"NetworkDir not found at {network_dir.path}.")
#     348 name = os.path.sep.join(network_dir.path.parts[-3:])
#     349 return network_dir, name
#
# ValueError: NetworkDir not found at /home/guardomayas/flyvis_data/results/flow/0000/000.

# %%
ensemble = EnsembleView(results_dir / "flow/0000")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 ensemble = EnsembleView(results_dir / "flow/0000")
#
# File ~/NUIN/flyvis/flyvis/network/ensemble_view.py:86, in EnsembleView.__init__(self, path, network_class, root_dir, connectome_getter, checkpoint_mapper, best_checkpoint_fn, best_checkpoint_fn_kwargs, recover_fn, try_sort)
#      84 if isinstance(path, Ensemble):
#      85     init_args = path._init_args
# ---> 86 super().__init__(*init_args)
#
# File ~/NUIN/flyvis/flyvis/network/ensemble.py:125, in Ensemble.__init__(self, path, network_class, root_dir, connectome_getter, checkpoint_mapper, best_checkpoint_fn, best_checkpoint_fn_kwargs, recover_fn, try_sort)
#     123     self.dir = path
#     124 elif isinstance(path, Path):
# --> 125     self.model_paths, self.path = model_paths_from_parent(path)
#     126     self.dir = EnsembleDir(self.path)
#     127 elif isinstance(path, str):
#
# File ~/NUIN/flyvis/flyvis/network/ensemble.py:901, in model_paths_from_parent(path)
#     892 def model_paths_from_parent(path: Path) -> Tuple[List[Path], Path]:
#     893     """Return a list of model paths from a parent path.
#     894
#     895     Args:
#    (...)    899         Tuple[List[Path], Path]: List of model paths and parent path.
#     900     """
# --> 901     model_paths = sorted(
#     902         filter(
#     903             lambda p: p.name.isnumeric() and p.is_dir(),
#     904             path.iterdir(),
#     905         )
#     906     )
#     907     return model_paths, path
#
# File ~/miniforge3/envs/flyvisenv/lib/python3.12/pathlib.py:1056, in Path.iterdir(self)
#    1050 def iterdir(self):
#    1051     """Yield path objects of the directory contents.
#    1052
#    1053     The children are yielded in arbitrary order, and the
#    1054     special entries '.' and '..' are not included.
#    1055     """
# -> 1056     for name in os.listdir(self):
#    1057         yield self._make_child_relpath(name)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/guardomayas/flyvis_data/results/flow/0000'
